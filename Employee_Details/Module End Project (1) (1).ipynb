# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ### 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
data=pd.read_excel('myexcel.xlsx')
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     160     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     171     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     165     203
# 454      Raul Neto       Utah Jazz      25       PG   24     169     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     160     256
# 456    Jeff Withey       Utah Jazz      24        C   26     161     231
# 457       Priyanka       Utah Jazz      34        C   25     160     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
team_sizes = data["Team"].value_counts()
team_sizes
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
total_employee=len(data)

# %%
total_employee
# Out:
# 458

# %%
team_percetage=(team_sizes/total_employee)*100

# %%
result=pd.DataFrame({'Team':team_sizes.index,
                     'Number_of_employee':team_sizes.values,
                    'percentage':team_percetage.values},)
result
# Out:
#                       Team  Number_of_employee  percentage
# 0     New Orleans Pelicans                  19    4.148472
# 1        Memphis Grizzlies                  18    3.930131
# 2                Utah Jazz                  16    3.493450
# 3          New York Knicks                  16    3.493450
# 4          Milwaukee Bucks                  16    3.493450
# 5            Brooklyn Nets                  15    3.275109
# 6   Portland Trail Blazers                  15    3.275109
# 7    Oklahoma City Thunder                  15    3.275109
# 8           Denver Nuggets                  15    3.275109
# 9       Washington Wizards                  15    3.275109
# 10              Miami Heat                  15    3.275109
# 11       Charlotte Hornets                  15    3.275109
# 12           Atlanta Hawks                  15    3.275109
# 13       San Antonio Spurs                  15    3.275109
# 14         Houston Rockets                  15    3.275109
# ...

# %% [markdown]
# ### 2.Segregate the employees w.r.t different positions.

# %%
position_dfs = {position: data[data['Position'] == position] for position in data['Position'].unique()}

for position, position_df in position_dfs.items():
    print(f"Employees in {position}:")
    print(position_df)
    print("\n")
# Out:
# Employees in PG:
#               Name                    Team  Number Position  Age  Height  \
# 0    Avery Bradley          Boston Celtics       0       PG   25     160
# 8     Terry Rozier          Boston Celtics      12       PG   22     175
# 9     Marcus Smart          Boston Celtics      36       PG   22     169
# 11   Isaiah Thomas          Boston Celtics       4       PG   27     165
# 19    Jarrett Jack           Brooklyn Nets       2       PG   32     178
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2       PG   30     160
# 443     Trey Burke               Utah Jazz       3       PG   23     172
# 445     Dante Exum               Utah Jazz      11       PG   20     172
# 453   Shelvin Mack               Utah Jazz       8       PG   26     165
# 454      Raul Neto               Utah Jazz      25       PG   24     169
#
#      Weight         College     Salary
# ...

# %% [markdown]
# ### 3.Find from which age group most of the employees belong to.

# %%
age_count=data["Age"].value_counts()
age_count
monstage=pd.DataFrame({'Age Group': age_count.index,
                    'Employees_with_same_age' : age_count.values})
monstage.head(1)
# Out:
#    Age Group  Employees_with_same_age
# 0         24                       47

# %% [markdown]
# ### 4.Find out under which team and position, spending in terms of salary is high.

# %%
high_salary=data["Salary"].max()
high_salary
# Out:
# 25000000.0

# %%
high_salary1=data.loc[data['Salary']==high_salary,['Team','Position','Salary']]
high_salary1
# Out:
#                    Team Position      Salary
# 109  Los Angeles Lakers       SF  25000000.0

# %% [markdown]
# ### 5.Find if there is any correlation between age and salary , represent it visually.

# %%
sns.set_style('dark')
plt.scatter(data['Salary'], data['Age'], color='red', marker='o', alpha=0.7)
plt.xlabel('Salary')
plt.ylabel('Age')
plt.title('Correlation Between Age and Salary')
plt.show()
